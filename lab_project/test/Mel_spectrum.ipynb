# %%
import os
import getpass
import matplotlib.pyplot as plt

from scipy import signal
from scipy.io import wavfile

# %%
user_name = getpass.getuser()
abspath_path = '/home/' + str(user_name) + '/AllFile/class/'
voice_path = abspath_path + 'voice/'
voice_listdir = os.listdir(voice_path)
listdir_number = len(voice_listdir)

# %%
sample_frequency, signalData = wavfile.read("wah_fuzz.wav")

# %%
plt.specgram(signalData[:,0], Fs=sample_frequency)
plt.axis([0,1.75,0,22000])
plt.savefig("C:/Users/HP/Desktop/test/test.jpg")

# %%
import numpy as np

# %% [markdown]
# ## library install
# conda install -c conda-forge librosa

# %%
import librosa
import numpy as np
# import soundfile as sf

y, S = librosa.load("C:/Users/Playdata/Documents/future_lab_project02/lab_project/data/Electronic" + "/" + "000" + ".wav",mono=False)

# %%
import matplotlib.pyplot as plt
import librosa.display

plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(S,ref=np.max),fmax=8000)

# plt.colorbar(format='%+2.0f dB')
# plt.title('Mel spectrogram')
# plt.tight_layout()
# plt.savefig("C:/Users/HP/Desktop/test/test.jpg")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-8c84f21bc7ec> in <module>()
#       3
#       4 plt.figure(figsize=(10, 4))
# ----> 5 librosa.display.specshow(librosa.power_to_db(S,ref=np.max),fmax=8000)
#       6
#       7 # plt.colorbar(format='%+2.0f dB')
#
# c:\users\playdata\anaconda3\lib\site-packages\librosa\display.py in specshow(data, x_coords, y_coords, x_axis, y_axis, sr, hop_length, fmin, fmax, bins_per_octave, ax, **kwargs)
#     680
#     681     # Get the x and y coordinates
# --> 682     y_coords = __mesh_coords(y_axis, y_coords, data.shape[0], **all_params)
#     683     x_coords = __mesh_coords(x_axis, x_coords, data.shape[1], **all_params)
#     684
#
# IndexError: tuple index out of range

# %%
conda install -c conda-forge librosa

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FE91-027E
#
#  C:\Users\HP\Desktop\test 디렉터리
#
# 2018-08-22  오후 09:10    <DIR>          .
# 2018-08-22  오후 09:10    <DIR>          ..
# 2018-08-22  오후 08:33    <DIR>          .ipynb_checkpoints
# 2018-08-22  오후 09:10           191,976 Mel_spectrum.ipynb
# 2018-08-22  오후 08:45           443,926 SampleAudio.mp3
# 2018-08-22  오후 08:45           443,926 SampleAudio_0.4mb.mp3
# 2018-08-22  오후 09:00            53,246 test.jpg
# 2018-08-22  오후 07:45           307,768 wah_fuzz.wav
#                5개 파일           1,440,842 바이트
#                3개 디렉터리  26,938,687,488 바이트 남음

# %%
from pydub import AudioSegment
AudioSegment.ffmpeg = "C:/Users/HP/Desktop/test/ffmpeg-20180821-7e0df59-win64-static/ffmpeg-20180821-7e0df59-win64-static/bin/ffmpeg.exe"
sound = AudioSegment.from_mp3("SampleAudio.mp3")
sound.export("file.wav", format="wav")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\utils.py:193: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-41b5a70042b5> in <module>()
#       1 from pydub import AudioSegment
#       2 AudioSegment.ffmpeg = "C:/Users/HP/Desktop/test/ffmpeg-20180821-7e0df59-win64-static/ffmpeg-20180821-7e0df59-win64-static/bin/ffmpeg.exe"
# ----> 3 sound = AudioSegment.from_mp3("SampleAudio.mp3")
#       4 sound.export("file.wav", format="wav")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\audio_segment.py in from_mp3(cls, file, parameters)
#     705     @classmethod
#     706     def from_mp3(cls, file, parameters=None):
# ...

# %%
help(Exception)
# Out:
# Help on class Exception in module builtins:
#
# class Exception(BaseException)
#  |  Common base class for all non-exit exceptions.
#  |
#  |  Method resolution order:
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(...)
#  |      helper for pickle
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
# ...

# %%
import ffmpeg

# %%
dir(ffmpeg)
# Out:
# ['Error',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_ffmpeg',
#  '_filters',
#  '_probe',
#  '_run',
#  '_utils',
#  '_view',
#  'colorchannelmixer',
#  'compile',
#  'concat',
#  'crop',
#  'dag',
#  'drawbox',
#  'drawtext',
#  'filter',
#  'filter_',
#  'filter_multi_output',
#  'get_args',
#  'hflip',
#  'hue',
#  'input',
#  'merge_outputs',
#  'nodes',
#  'output',
#  'overlay',
#  'overwrite_output',
#  'probe',
#  'run',
#  'setpts',
#  'trim',
#  'unicode_literals',
#  'vflip',
#  'view',
#  'zoompan']

# %%
# %cwd
# Out:
# UsageError: Line magic function `%cwd` not found.

# %%
test = ffmpeg.input('C:/Users/Playdata/DocumentsPython Scriptslab_projecttest/SampleAudio.mp3')
test = ffmpeg.output(test, 'C:/Users/Playdata/DocumentsPython Scriptslab_projecttest/SampleAudio.mp3')

# %%
ffmpeg.run(test)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-a17b01e411ff> in <module>()
# ----> 1 ffmpeg.run(test)
#
# c:\users\playdata\anaconda3\lib\site-packages\ffmpeg\_run.py in run(stream_spec, cmd, capture_stdout, capture_stderr, input, quiet, overwrite_output)
#     206     stdout_stream = subprocess.PIPE if capture_stdout or quiet else None
#     207     stderr_stream = subprocess.PIPE if capture_stderr or quiet else None
# --> 208     p = subprocess.Popen(args, stdin=stdin_stream, stdout=stdout_stream, stderr=stderr_stream)
#     209     out, err = p.communicate(input)
#     210     retcode = p.poll()
#
# ...
